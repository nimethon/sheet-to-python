# %% [markdown]
# <a href="https://colab.research.google.com/github/nimethon/sheet-to-python/blob/main/google_sheet_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install gspread
#check version: gspread.__version__
#pip install --upgrade gspread

# %%
import pandas as pd
import gspread

# %%
import gspread as gs
import pandas as pd
google_cloud = gs.service_account(filename="/content/sample_data/python-410018-348e5baa13e6.json")
sheet = google_cloud.open_by_url('https://docs.google.com/spreadsheets/d/1e3yOg39_UWo-LjwDkqtgSa9-Zra1DHhzv_nIGIG-xZE/edit#gid=0')
ws = sheet.worksheet('group-1')
df = pd.DataFrame(ws.get_all_records())
df.head()
# Out:
#      name    roll
# 0  methon  200501
# 1  tanvir  200503
# 2     jui  200504
# 3    arif  200505
# 4  update     n/a

# %%
ws2 = sheet.worksheet('group-2')
df = pd.DataFrame(ws2.get_all_records())
df.head()
# Out:
#      name    roll
# 0    urme  200506
# 1    mery  200507
# 2   sakib  200508
# 3  arafat  200509
